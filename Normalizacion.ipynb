# %%
import pandas as pd

df_constructors=pd.read_json("constructors.json", lines = True)

# %%
df_constructors.isnull().values.any()
# Out:
# False

# %%
df_constructors.isnull().sum().sum()
# Out:
# 0

# %%
df_constructors.shape
# Out:
# (211, 5)

# %%
df_constructors.to_csv('df_constructors.csv')

# %%
df_drivers=pd.read_csv("drivers.csv")

# %%
df_pit_stops=pd.read_csv("pit_stops.csv")

# %%
df_pit_stops.isnull().sum().sum()
# Out:
# 0

# %%
df_1=pd.read_csv("lap_times_split_1.csv")
df_2=pd.read_csv("lap_times_split_2.csv")
df_3=pd.read_csv("lap_times_split_3.csv")
df_4=pd.read_csv("lap_times_split_4.csv")
df_5=pd.read_csv("lap_times_split_5.csv")

# %%
df_1.columns =['Name1', 'Name2', 'Name3', 'Name4','Name5','Name6'] 
df_2.columns =['Name1', 'Name2', 'Name3', 'Name4','Name5','Name6'] 
df_3.columns =['Name1', 'Name2', 'Name3', 'Name4','Name5','Name6'] 
df_4.columns =['Name1', 'Name2', 'Name3', 'Name4','Name5','Name6'] 
df_5.columns =['Name1', 'Name2', 'Name3', 'Name4','Name5','Name6']

# %%
lap_times_split=pd.concat([df_1, df_2, df_3,df_4,df_5], ignore_index=True)

# %%
lap_times_split
# Out:
#         qualifyId  raceId  driverId  constructorId  number  position  \
# 0          5002.0   861.0     811.0            3.0    19.0      13.0
# 1          5003.0   861.0     814.0           10.0    11.0      14.0
# 2          5004.0   861.0     817.0            5.0    16.0      15.0
# 3          5005.0   861.0     807.0           10.0    12.0      16.0
# 4          5006.0   861.0     155.0           15.0    14.0      17.0
# ...           ...     ...       ...            ...     ...       ...
# 394591        NaN     NaN       NaN            NaN     NaN       NaN
# 394592        NaN     NaN       NaN            NaN     NaN       NaN
# 394593        NaN     NaN       NaN            NaN     NaN       NaN
# 394594        NaN     NaN       NaN            NaN     NaN       NaN
# 394595        NaN     NaN       NaN            NaN     NaN       NaN
#
#               q1        q2   q3   Name1  Name2  Name3  Name4     Name5  \
# ...

# %%
lap_times_split.drop_duplicates()
# Out:
#         Name1  Name2  Name3  Name4     Name5   Name6
# 0         841     20      2      1  1:33.006   93006
# 1         841     20      3      1  1:32.713   92713
# 2         841     20      4      1  1:32.803   92803
# 3         841     20      5      1  1:32.342   92342
# 4         841     20      6      1  1:32.605   92605
# ...       ...    ...    ...    ...       ...     ...
# 490894   1047    815      4     17  1:44.762  104762
# 490895   1047    815      5     16  1:43.786  103786
# 490896   1047    815      6     15  1:43.263  103263
# 490897   1047    815      7     15  1:45.123  105123
# 490898   1047    815      8     14  1:44.231  104231
#
# [490899 rows x 6 columns]

# %%
lap_times_split.to_csv('lap_times_split.csv')

# %%
qs1=pd.read_json("qualifying_split_1.json")
qs2=pd.read_json("qualifying_split_2.json")

# %%
qualifying_split=pd.concat([qs1,qs2], ignore_index=True)

# %%
qualifying_split
# Out:
#       qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0             1      18         1              1      22         1  1:26.572
# 1             2      18         9              2       4         2  1:26.103
# 2             3      18         5              1      23         3  1:25.664
# 3             4      18        13              6       2         4  1:25.994
# 4             5      18         2              2       3         5  1:25.960
# ...         ...     ...       ...            ...     ...       ...       ...
# 8689       8730    1047         8             51       7        16  1:37.555
# 8690       8731    1047       825            210      20        17  1:37.863
# 8691       8732    1047       847              3      63        18  1:38.045
# 8692       8733    1047       850            210      51        19  1:38.173
# 8693       8734    1047       849              3       6        20  1:38.443
#
#             q2        q3
# ...

# %%
qualifying_split.isnull().sum()
# Out:
# qualifyId        0
# raceId           0
# driverId         0
# constructorId    0
# number           0
# position         0
# q1               0
# q2               0
# q3               0
# dtype: int64

# %%
qualifying_split=qualifying_split.replace('\\N','Sin Dato')

# %%
qualifying_split
# Out:
#       qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0             1      18         1              1      22         1  1:26.572
# 1             2      18         9              2       4         2  1:26.103
# 2             3      18         5              1      23         3  1:25.664
# 3             4      18        13              6       2         4  1:25.994
# 4             5      18         2              2       3         5  1:25.960
# ...         ...     ...       ...            ...     ...       ...       ...
# 8689       8730    1047         8             51       7        16  1:37.555
# 8690       8731    1047       825            210      20        17  1:37.863
# 8691       8732    1047       847              3      63        18  1:38.045
# 8692       8733    1047       850            210      51        19  1:38.173
# 8693       8734    1047       849              3       6        20  1:38.443
#
#             q2        q3
# ...

# %%
qualifying_split.to_csv('qualifying_split.csv')

# %%
results=pd.read_json("results.json",lines = True)

# %%
results
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 24955     24961    1047       841             51     99    14       16
# 24956     24962    1047       849              3      6    18       17
# 24957     24963    1047       825            210     20    20       18
# 24958     24964    1047       850            210     51    17       19
# 24959     24965    1047       815            211     11    19       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
results=results.replace('\\N','Sin Dato')

# %%
results
# Out:
#        resultId  raceId  driverId  constructorId number  grid  position  \
# 0             1      18         1              1     22     1         1
# 1             2      18         2              2      3     5         2
# 2             3      18         3              3      7     7         3
# 3             4      18         4              4      5    11         4
# 4             5      18         5              1     23     3         5
# ...         ...     ...       ...            ...    ...   ...       ...
# 24955     24961    1047       841             51     99    14        16
# 24956     24962    1047       849              3      6    18        17
# 24957     24963    1047       825            210     20    20        18
# 24958     24964    1047       850            210     51    17        19
# 24959     24965    1047       815            211     11    19  Sin Dato
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
results.to_csv('results.csv')

# %%
races=pd.read_csv("races.csv")

# %%
races.isnull().sum()
# Out:
# raceId       0
# year         0
# round        0
# circuitId    0
# name         0
# date         0
# time         0
# url          0
# dtype: int64

# %%
races=races.replace('\\N','Sin Dato')

# %%
df_constructors=pd.read_csv(".\Archivos en Csv\df_constructors.csv")

# %%
df_constructors.dtypes
# Out:
# Unnamed: 0         int64
# constructorId      int64
# constructorRef    object
# name              object
# nationality       object
# url               object
# dtype: object

# %%
drivers=pd.read_csv(".\Archivos en Csv\drivers.csv")

# %%
drivers=drivers.replace('\\N','Sin Dato')

# %%
drivers.to_csv('drivers.csv')

# %%
drivers
# Out:
#      driverId          driverRef    number code name/forename name/surname  \
# 0           1           hamilton        44  HAM         Lewis     Hamilton
# 1           2           heidfeld  Sin Dato  HEI          Nick     Heidfeld
# 2           3            rosberg         6  ROS          Nico      Rosberg
# 3           4             alonso        14  ALO      Fernando       Alonso
# 4           5         kovalainen  Sin Dato  KOV        Heikki   Kovalainen
# ..        ...                ...       ...  ...           ...          ...
# 848       850  pietro_fittipaldi        51  FIT        Pietro   Fittipaldi
# 849       851             aitken        89  AIT          Jack       Aitken
# 850       852            tsunoda  Sin Dato  TSU          Yuki      Tsunoda
# 851       853            mazepin  Sin Dato  MAZ        Nikita      Mazepin
# 852       854    mick_schumacher  Sin Dato  SCH          Mick   Schumacher
#
# ...

# %%
races=pd.read_csv("races.csv")

# %%
races
# Out:
#       Unnamed: 0  raceId  year  round  circuitId                      name  \
# 0              0       1  2009      1          1     Australian Grand Prix
# 1              1       2  2009      2          2      Malaysian Grand Prix
# 2              2       3  2009      3         17        Chinese Grand Prix
# 3              3       4  2009      4          3        Bahrain Grand Prix
# 4              4       5  2009      5          4        Spanish Grand Prix
# ...          ...     ...   ...    ...        ...                       ...
# 1053        1053    1069  2021     18         69  United States Grand Prix
# 1054        1054    1070  2021     19         32    Mexico City Grand Prix
# 1055        1055    1071  2021     20         18      Brazilian Grand Prix
# 1056        1056    1072  2021     22         77  Saudi Arabian Grand Prix
# 1057        1057    1073  2021     23         24      Abu Dhabi Grand Prix
#
# ...

# %%
races.dtypes
# Out:
# Unnamed: 0     int64
# raceId         int64
# year           int64
# round          int64
# circuitId      int64
# name          object
# date          object
# time          object
# url           object
# dtype: object

# %%
results=pd.read_csv("results.csv")

# %%
results=results.replace('Sin Dato',0)

# %%
results['position'] = results['position'].astype('int64')

# %%
results.min()
# Out:
# C:\Users\Jorge\AppData\Local\Temp\ipykernel_22704\3022933592.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   results.min()
# Unnamed: 0         0
# resultId           1
# raceId             1
# driverId           1
# constructorId      1
# grid               0
# position           1
# positionText       1
# positionOrder      1
# points           0.0
# laps               0
# statusId           1
# dtype: object

# %%
results['position']=results['position'].replace(0,33)

# %%
results
# Out:
#        Unnamed: 0  resultId  raceId  driverId  constructorId number  grid  \
# 0               0         1      18         1              1     22     1
# 1               1         2      18         2              2      3     5
# 2               2         3      18         3              3      7     7
# 3               3         4      18         4              4      5    11
# 4               4         5      18         5              1     23     3
# ...           ...       ...     ...       ...            ...    ...   ...
# 24955       24955     24961    1047       841             51     99    14
# 24956       24956     24962    1047       849              3      6    18
# 24957       24957     24963    1047       825            210     20    20
# 24958       24958     24964    1047       850            210     51    17
# 24959       24959     24965    1047       815            211     11    19
#
#       position positionText  positionOrder  points  laps         time  \
# ...

# %%
results
# Out:
#        Unnamed: 0  resultId  raceId  driverId  constructorId number  grid  \
# 0               0         1      18         1              1     22     1
# 1               1         2      18         2              2      3     5
# 2               2         3      18         3              3      7     7
# 3               3         4      18         4              4      5    11
# 4               4         5      18         5              1     23     3
# ...           ...       ...     ...       ...            ...    ...   ...
# 24955       24955     24961    1047       841             51     99    14
# 24956       24956     24962    1047       849              3      6    18
# 24957       24957     24963    1047       825            210     20    20
# 24958       24958     24964    1047       850            210     51    17
# 24959       24959     24965    1047       815            211     11    19
#
#        position positionText  positionOrder  points  laps         time  \
# ...

# %%
results=results.replace('Sin Dato',"19")

# %%
results.to_csv('results.csv')

# %%
results
# Out:
#        Unnamed: 0  resultId  raceId  driverId  constructorId number  grid  \
# 0               0         1      18         1              1     22     1
# 1               1         2      18         2              2      3     5
# 2               2         3      18         3              3      7     7
# 3               3         4      18         4              4      5    11
# 4               4         5      18         5              1     23     3
# ...           ...       ...     ...       ...            ...    ...   ...
# 24955       24955     24961    1047       841             51     99    14
# 24956       24956     24962    1047       849              3      6    18
# 24957       24957     24963    1047       825            210     20    20
# 24958       24958     24964    1047       850            210     51    17
# 24959       24959     24965    1047       815            211     11    19
#
#        position positionText  positionOrder  points  laps         time  \
# ...

# %%
results.dtypes
# Out:
# Unnamed: 0           int64
# resultId             int64
# raceId               int64
# driverId             int64
# constructorId        int64
# number              object
# grid                 int64
# position             int64
# positionText        object
# positionOrder        int64
# points             float64
# laps                 int64
# time                object
# milliseconds        object
# fastestLap          object
# rank                object
# fastestLapTime      object
# fastestLapSpeed     object
# statusId             int64
# dtype: object
